# %% [markdown]
# # GitHub Stars
#
# SPDX-License-Identifier: 0BSD
#
# Query a GitHub user’s starred repositories and their topics

# %%
import collections
import logging

import stars

# %%
logging.basicConfig(level=logging.INFO)

# %%
topics = stars.extract_topics(stars.get_starred_repos('EliahKagan'))
# Out:
# INFO:root:No saved results for 'EliahKagan'. Using GitHub API.

# %%
topic_frequencies = {topic: len(row) for topic, row in topics.items()}
collections.Counter(topic_frequencies).most_common()
# Out:
# [('hacktoberfest', 60),
#  ('python', 48),
#  ('javascript', 18),
#  ('dotnet', 17),
#  ('vscode', 16),
#  ('windows', 16),
#  ('visual-studio-code', 12),
#  ('ruby', 12),
#  ('linter', 11),
#  ('c', 11),
#  ('vscode-extension', 11),
#  ('linux', 10),
#  ('jupyter', 10),
#  ('git', 10),
#  ('java', 10),
#  ('compiler', 9),
#  ('rust', 9),
#  ('c-sharp', 8),
#  ('csharp', 8),
#  ('visual-studio', 7),
#  ('editor', 7),
#  ('powershell', 7),
#  ('quantum', 7),
#  ('containers', 7),
#  ('devcontainers', 7),
#  ('machine-learning', 7),
#  ('android', 6),
#  ('macos', 6),
#  ('terminal', 6),
#  ('typescript', 6),
#  ('shell', 6),
#  ('cli', 6),
#  ('cpp', 6),
#  ('c-plus-plus', 6),
#  ('qsharp', 6),
#  ('cross-platform', 5),
#  ('scoop', 5),
#  ('markdown', 5),
#  ('ide', 5),
#  ('language-server', 5),
#  ('crystal', 5),
#  ('data-science', 5),
#  ('natural-language-processing', 5),
#  ('qdk', 5),
#  ('quantum-development-kit', 5),
#  ('scoop-bucket', 4),
#  ('chrome-extension', 4),
#  ('firefox-extension', 4),
#  ('gtk', 4),
#  ('design', 4),
#  ('font', 4),
#  ('command-line', 4),
#  ('flake8', 4),
#  ('python3', 4),
#  ('static-analysis', 4),
#  ('static-code-analysis', 4),
#  ('flake8-plugin', 4),
#  ('closember', 4),
#  ('pip', 4),
#  ('syntax-highlighting', 4),
#  ('electron', 4),
#  ('video', 4),
#  ('css', 4),
#  ('html', 4),
#  ('nodejs', 4),
#  ('package-manager', 4),
#  ('language', 4),
#  ('haskell', 4),
#  ('docker', 4),
#  ('firefox', 4),
#  ('nlp', 4),
#  ('types', 4),
#  ('learning', 4),
#  ('avalonia', 3),
#  ('browser', 3),
#  ('desktop', 3),
#  ('dark-theme', 3),
#  ('webextension', 3),
#  ('testing', 3),
#  ('jackson', 3),
#  ('json', 3),
#  ('github', 3),
#  ('kotlin', 3),
#  ('console', 3),
#  ('documentation', 3),
#  ('formatter', 3),
#  ('linter-flake8', 3),
#  ('pep8', 3),
#  ('style-guide', 3),
#  ('openai', 3),
#  ('afdko', 3),
#  ('fonts', 3),
#  ('opentype-fonts', 3),
#  ('otf', 3),
#  ('ttf-fonts', 3),
#  ('variable-fonts', 3),
#  ('cplusplus', 3),
#  ('go', 3),
#  ('http', 3),
#  ('fsharp', 3),
#  ('roslyn', 3),
#  ('graphviz', 3),
#  ('deep-learning', 3),
#  ('spacy', 3),
#  ('pytorch', 3),
#  ('metaprogramming', 3),
#  ('jupyter-notebook', 3),
#  ('jupyterlab', 3),
#  ('asyncio', 3),
#  ('open-source', 3),
#  ('virtual-machine', 3),
#  ('qt', 3),
#  ('quantum-computing', 3),
#  ('cmake', 3),
#  ('runtime', 3),
#  ('audio', 3),
#  ('multimedia', 3),
#  ('packaging', 3),
#  ('gui', 2),
#  ('ios', 2),
#  ('xaml', 2),
#  ('gruvbox', 2),
#  ('sublime-text', 2),
#  ('theme', 2),
#  ('games', 2),
#  ('userscript', 2),
#  ('winforms', 2),
#  ('wpf', 2),
#  ('intellisense', 2),
#  ('refactorings', 2),
#  ('https', 2),
#  ('cookies', 2),
#  ('privacy', 2),
#  ('gitlab', 2),
#  ('torrent', 2),
#  ('ligatures', 2),
#  ('programming-ligatures', 2),
#  ('programming-language', 2),
#  ('math', 2),
#  ('azure', 2),
#  ('security', 2),
#  ('vpn', 2),
#  ('analyzer', 2),
#  ('powershell-gallery', 2),
#  ('netcore', 2),
#  ('win32', 2),
#  ('complexity-analysis', 2),
#  ('styleguide', 2),
#  ('linter-plugin', 2),
#  ('portable', 2),
#  ('scoop-apps', 2),
#  ('algorithms', 2),
#  ('data-structures', 2),
#  ('rust-lang', 2),
#  ('google', 2),
#  ('floss', 2),
#  ('open-source-licensing', 2),
#  ('bittorrent', 2),
#  ('library', 2),
#  ('atom', 2),
#  ('vscode-theme', 2),
#  ('bash', 2),
#  ('github-actions', 2),
#  ('toml', 2),
#  ('doom', 2),
#  ('gplv2', 2),
#  ('heretic', 2),
#  ('hexen', 2),
#  ('clang', 2),
#  ('docs', 2),
#  ('prompt', 2),
#  ('repl', 2),
#  ('tutorial', 2),
#  ('client', 2),
#  ('firefox-addon', 2),
#  ('php', 2),
#  ('dotnet-core', 2),
#  ('visual-basic', 2),
#  ('microsoft', 2),
#  ('sdk', 2),
#  ('extension', 2),
#  ('nlp-library', 2),
#  ('models', 2),
#  ('bert', 2),
#  ('language-model', 2),
#  ('fish', 2),
#  ('concurrency', 2),
#  ('performance', 2),
#  ('action', 2),
#  ('openbsd', 2),
#  ('actions', 2),
#  ('ci', 2),
#  ('rails', 2),
#  ('devcontainer', 2),
#  ('golang', 2),
#  ('model-hub', 2),
#  ('pretrained-models', 2),
#  ('decompiler', 2),
#  ('dotnetcore', 2),
#  ('ipython', 2),
#  ('notebook', 2),
#  ('retry', 2),
#  ('jitsi', 2),
#  ('jitsi-meet', 2),
#  ('video-conferencing', 2),
#  ('webrtc', 2),
#  ('mypy', 2),
#  ('jvm', 2),
#  ('ruby-language', 2),
#  ('jupyterlab-extension', 2),
#  ('msgpack', 2),
#  ('numpy', 2),
#  ('lxqt', 2),
#  ('qt5', 2),
#  ('dot', 2),
#  ('data-visualization', 2),
#  ('wsl', 2),
#  ('framework', 2),
#  ('ffmpeg', 2),
#  ('player', 2),
#  ('svg', 2),
#  ('art', 2),
#  ('education', 2),
#  ('processing', 2),
#  ('lint', 2),
#  ('unit-testing', 2),
#  ('typing', 2),
#  ('rspec', 2),
#  ('rubocop', 2),
#  ('vlc', 2),
#  ('vim', 2),
#  ('mediawiki', 2),
#  ('wiki', 2),
#  ('wikipedia', 2),
#  ('office', 1),
#  ('wordprocessor', 1),
#  ('app-framework', 1),
#  ('avaloniaui', 1),
#  ('mobile', 1),
#  ('wasm', 1),
#  ('adaptive', 1),
#  ('color-scheme', 1),
#  ('gruvbox-color-scheme', 1),
#  ('light-theme', 1),
#  ('package-control', 1),
#  ('sublime-text-3', 1),
#  ('syntax-theme', 1),
#  ('open-source-game', 1),
#  ('regex', 1),
#  ('spam', 1),
#  ('ruby-on-rails', 1),
#  ('web-dashboard', 1),
#  ('mvvm', 1),
#  ('uwp', 1),
#  ('uwp-apps', 1),
#  ('uwp-toolkit', 1),
#  ('windows-10', 1),
#  ('windows-app-sdk', 1),
#  ('windows-sdk', 1),
#  ('windows-toolkit', 1),
#  ('windowsappsdk', 1),
#  ('winui', 1),
#  ('winui3', 1),
#  ('xaml-islands', 1),
#  ('autopep8', 1),
#  ('extract', 1),
#  ('pydocstyle', 1),
#  ('pylint', 1),
#  ('python-3-6', 1),
#  ('python-terminal', 1),
#  ('rename-refactorings', 1),
#  ('scientific', 1),
#  ('sort-imports', 1),
#  ('ruleset', 1),
#  ('browser-fingerprinting', 1),
#  ('fingerprinting', 1),
#  ('tracking', 1),
#  ('java-json', 1),
#  ('java-json-library', 1),
#  ('jackson-databind', 1),
#  ('aad', 1),
#  ('authentication', 1),
#  ('azure-devops', 1),
#  ('azure-repos', 1),
#  ('bitbucket', 1),
#  ('credential', 1),
#  ('typeface', 1),
#  ('dlr', 1),
#  ('ironpython', 1),
#  ('api', 1),
#  ('couchpotato', 1),
#  ('duckietv', 1),
#  ('indexer', 1),
#  ('jackett', 1),
#  ('lidarr', 1),
#  ('medusa', 1),
#  ('mylar3', 1),
#  ('nefarious', 1),
#  ('newznab', 1),
#  ('proxy', 1),
#  ('radarr', 1),
#  ('rss', 1),
#  ('rss-proxy', 1),
#  ('sickrage', 1),
#  ('sonarr', 1),
#  ('torznab', 1),
#  ('trackers', 1),
#  ('coding-font', 1),
#  ('monospaced-font', 1),
#  ('programming-font', 1),
#  ('code-editor', 1),
#  ('intellij', 1),
#  ('intellij-community', 1),
#  ('intellij-platform', 1),
#  ('gradle-plugin', 1),
#  ('intellij-plugin', 1),
#  ('kotlin-library', 1),
#  ('maven-plugin', 1),
#  ('haskell-language', 1),
#  ('highlighting', 1),
#  ('katex', 1),
#  ('latex', 1),
#  ('math-typesetting', 1),
#  ('libreoffice', 1),
#  ('tdf', 1),
#  ('conemu', 1),
#  ('customizable', 1),
#  ('powershell-documentation', 1),
#  ('collaboration', 1),
#  ('pair-programming', 1),
#  ('nuget', 1),
#  ('gui-application', 1),
#  ('nuget-client', 1),
#  ('nuget-packages', 1),
#  ('cpan', 1),
#  ('perl', 1),
#  ('perl5', 1),
#  ('scriptanalyzer', 1),
#  ('ssh', 1),
#  ('openssh', 1),
#  ('openssh-server', 1),
#  ('extensions', 1),
#  ('darwin', 1),
#  ('operating-system', 1),
#  ('stylelint', 1),
#  ('auto-formatter', 1),
#  ('cleaner', 1),
#  ('isort', 1),
#  ('python-utility', 1),
#  ('sorting-imports', 1),
#  ('complexity', 1),
#  ('flake8-extensions', 1),
#  ('mccabe', 1),
#  ('code-quality', 1),
#  ('binding', 1),
#  ('ffi', 1),
#  ('python-c-api', 1),
#  ('64-bit', 1),
#  ('doom3', 1),
#  ('gaming', 1),
#  ('idtech4', 1),
#  ('modding', 1),
#  ('pbr', 1),
#  ('typechecking', 1),
#  ('chatbot', 1),
#  ('naa', 1),
#  ('stack-overflow', 1),
#  ('stack-exchange', 1),
#  ('stack-exchange-chat', 1),
#  ('stackoverflow', 1),
#  ('amazon-corretto', 1),
#  ('bellsoft-liberica', 1),
#  ('eclipse-temurin', 1),
#  ('ibm-semeru', 1),
#  ('jdk', 1),
#  ('jdk11', 1),
#  ('jdk17', 1),
#  ('jdk8', 1),
#  ('microsoft-jdk', 1),
#  ('ojdkbuild', 1),
#  ('oracle-java', 1),
#  ('sapmachine', 1),
#  ('scoop-java', 1),
#  ('zulu', 1),
#  ('installer', 1),
#  ('comparer', 1),
#  ('comparers', 1),
#  ('comparison', 1),
#  ('comparison-library', 1),
#  ('equality', 1),
#  ('equality-comparers', 1),
#  ('icomparable', 1),
#  ('icomparer', 1),
#  ('iequalitycomparer', 1),
#  ('sort', 1),
#  ('deque', 1),
#  ('sublime-snippets', 1),
#  ('sublime-text-package', 1),
#  ('gpt3', 1),
#  ('alibaba', 1),
#  ('argos', 1),
#  ('baidu', 1),
#  ('bing', 1),
#  ('caiyun', 1),
#  ('deepl', 1),
#  ('iciba', 1),
#  ('iflytek', 1),
#  ('itranslate', 1),
#  ('lingvanex', 1),
#  ('mglip', 1),
#  ('niutrans', 1),
#  ('papago', 1),
#  ('reverso', 1),
#  ('sogou', 1),
#  ('tencent', 1),
#  ('utibet', 1),
#  ('yandex', 1),
#  ('youdao', 1),
#  ('x11', 1),
#  ('qemu', 1),
#  ('tcg', 1),
#  ('bookmark', 1),
#  ('delphi', 1),
#  ('apache-maven', 1),
#  ('build-management', 1),
#  ('maven', 1),
#  ('monokai', 1),
#  ('monokai-theme', 1),
#  ('avi', 1),
#  ('shellcheck', 1),
#  ('shellcheck-action', 1),
#  ('bower', 1),
#  ('front-end', 1),
#  ('carbon-lang', 1),
#  ('experimental', 1),
#  ('experimental-language', 1),
#  ('fps', 1),
#  ('fps-game', 1),
#  ('retro', 1),
#  ('retrogaming', 1),
#  ('sdl', 1),
#  ('sdl2', 1),
#  ('strife', 1),
#  ('clangd', 1),
#  ('assembly', 1),
#  ('dlang', 1),
#  ('ispc', 1),
#  ('swift', 1),
#  ('conda-forge', 1),
#  ('conda', 1),
#  ('package-management', 1),
#  ('efficiency', 1),
#  ('gitbook', 1),
#  ('curl', 1),
#  ('ftp', 1),
#  ('gopher', 1),
#  ('imaps', 1),
#  ('ldap', 1),
#  ('libcurl', 1),
#  ('mqtt', 1),
#  ('pop3', 1),
#  ('scp', 1),
#  ('sftp', 1),
#  ('transfer-data', 1),
#  ('transferring-data', 1),
#  ('user-agent', 1),
#  ('websocket', 1),
#  ('chocolatey', 1),
#  ('powershell-module', 1),
#  ('powershell-profile', 1),
#  ('powershell-profile-script', 1),
#  ('powershell-prompt', 1),
#  ('profile-script', 1),
#  ('psgallery', 1),
#  ('accessibility', 1),
#  ('dark-mode', 1),
#  ('darkmode', 1),
#  ('eye-care', 1),
#  ('night-mode', 1),
#  ('nightmode', 1),
#  ('dependencies', 1),
#  ('elixir', 1),
#  ('elm', 1),
#  ('terraform', 1),
#  ('functional-programming', 1),
#  ('tools', 1),
#  ('dotnet-interactive', 1),
#  ('interactive-programming', 1),
#  ('notebooks', 1),
#  ('polyglot', 1),
#  ('polyglot-dev', 1),
#  ('build', 1),
#  ('msbuild', 1),
#  ('windows-forms', 1),
#  ('chrome', 1),
#  ('web-extension', 1),
#  ('tool', 1),
#  ('marketplace', 1),
#  ('registry', 1),
#  ('theia', 1),
#  ('monospace', 1),
#  ('ofl', 1),
#  ('pacific-northwest', 1),
#  ('ai', 1),
#  ('artificial-intelligence', 1),
#  ('cython', 1),
#  ('entity-linking', 1),
#  ('named-entity-recognition', 1),
#  ('neural-network', 1),
#  ('neural-networks', 1),
#  ('text-classification', 1),
#  ('tokenization', 1),
#  ('machine-learning-models', 1),
#  ('spacy-models', 1),
#  ('statistical-models', 1),
#  ('gpt-2', 1),
#  ('huggingface', 1),
#  ('natural-language-understanding', 1),
#  ('pytorch-model', 1),
#  ('spacy-extension', 1),
#  ('spacy-pipeline', 1),
#  ('transfer-learning', 1),
#  ('xlnet', 1),
#  ('iterators', 1),
#  ('special-methods', 1),
#  ('chrono', 1),
#  ('formatting', 1),
#  ('multiplatform', 1),
#  ('output', 1),
#  ('printf', 1),
#  ('ld-preload', 1),
#  ('link-checker', 1),
#  ('link-checking', 1),
#  ('markdown-link-check', 1),
#  ('scheduled-runs', 1),
#  ('cpu', 1),
#  ('disk', 1),
#  ('freebsd', 1),
#  ('memory', 1),
#  ('monitoring', 1),
#  ('netbsd', 1),
#  ('osx', 1),
#  ('ps', 1),
#  ('psutil', 1),
#  ('sensors', 1),
#  ('system-monitoring', 1),
#  ('top', 1),
#  ('git-client', 1),
#  ('git-gui', 1),
#  ('gitextensions', 1),
#  ('advanced-security', 1),
#  ('code-scanning', 1),
#  ('codeql', 1),
#  ('semmle-ql', 1),
#  ('works-with-codespaces', 1),
#  ('gitignore', 1),
#  ('language-grammars', 1),
#  ('language-statistics', 1),
#  ('linguistic', 1),
#  ('3d', 1),
#  ('3d-models', 1),
#  ('augmented-reality', 1),
#  ('glb', 1),
#  ('gltf', 1),
#  ('magic-leap', 1),
#  ('model-viewer', 1),
#  ('three-js', 1),
#  ('webcomponents', 1),
#  ('webxr', 1),
#  ('google-fonts', 1),
#  ('inconsolata', 1),
#  ('inconsolata-fonts', 1),
#  ('blocker', 1),
#  ('browser-extension', 1),
#  ('chromium', 1),
#  ('ublock', 1),
#  ('ublock-origin', 1),
#  ('haskell-language-server', 1),
#  ('lsp', 1),
#  ('flax', 1),
#  ('jax', 1),
#  ('language-models', 1),
#  ('pytorch-transformers', 1),
#  ('seq2seq', 1),
#  ('speech-recognition', 1),
#  ('tensorflow', 1),
#  ('transformer', 1),
#  ('hy', 1),
#  ('lisps', 1),
#  ('macros', 1),
#  ('decompile', 1),
#  ('decompiler-engine', 1),
#  ('ilspy', 1),
#  ('mono', 1),
#  ('pdb', 1),
#  ('unity', 1),
#  ('ipython-kernel', 1),
#  ('kernel', 1),
#  ('failure', 1),
#  ('retry-library', 1),
#  ('commonmark', 1),
#  ('converter', 1),
#  ('document', 1),
#  ('markup', 1),
#  ('pandoc', 1),
#  ('presentation', 1),
#  ('publishing', 1),
#  ('debian', 1),
#  ('deep-video', 1),
#  ('scalable-video-conferences', 1),
#  ('sfu', 1),
#  ('video-communication', 1),
#  ('flake8-plugins', 1),
#  ('pyproject', 1),
#  ('pyproject-toml', 1),
#  ('vscode-plugin', 1),
#  ('vsls', 1),
#  ('github-action', 1),
#  ('invokedynamic', 1),
#  ('jruby', 1),
#  ('server', 1),
#  ('diff', 1),
#  ('diffing', 1),
#  ('hg', 1),
#  ('mercurial', 1),
#  ('merge', 1),
#  ('merge-driver', 1),
#  ('mergetool', 1),
#  ('vcs', 1),
#  ('version-control', 1),
#  ('cargo', 1),
#  ('developer-tools', 1),
#  ('async', 1),
#  ('async-await', 1),
#  ('asynchronous-programming', 1),
#  ('coroutines', 1),
#  ('coroutines-ts', 1),
#  ('msvc', 1),
#  ('law', 1),
#  ('legal', 1),
#  ('licensing', 1),
#  ('ruby-gem', 1),
#  ('asynchronous', 1),
#  ('backoff', 1),
#  ('decorators', 1),
#  ('exceptions', 1),
#  ('exponential', 1),
#  ('retrying', 1),
#  ('synchronous', 1),
#  ('cgroups', 1),
#  ('namespaces', 1),
#  ('dynamic-analysis', 1),
#  ('sanitizer', 1),
#  ('code-generation', 1),
#  ('intermediate-representation', 1),
#  ('llvm', 1),
#  ('optimization', 1),
#  ('lxde', 1),
#  ('terminal-emulators', 1),
#  ('vte', 1),
#  ('desktop-environment', 1),
#  ('archiver', 1),
#  ('animated-transitions', 1),
#  ('d3', 1),
#  ('d3-module', 1),
#  ('d3v4', 1),
#  ('graph-layout', 1),
#  ('graphviz-dot', 1),
#  ('matplotlib', 1),
#  ('plotting', 1),
#  ('tk', 1),
#  ('wx', 1),
#  ('emscripten', 1),
#  ('mdn', 1),
#  ('reference', 1),
#  ('web-development', 1),
#  ('web-standards', 1),
#  ('learning-js', 1),
#  ('learning-to-code', 1),
#  ('mdn-docs', 1),
#  ('devcontainer-feature', 1),
#  ('fisher', 1),
#  ('homebrew', 1),
#  ('visual-studio-code-extension', 1),
#  ('coding-kata', 1),
#  ('quantum-programming', 1),
#  ('tutorial-exercises', 1),
#  ('tutorials', 1),
#  ('monaco-editor', 1),
#  ('code-analysis', 1),
#  ('language-server-protocol', 1),
#  ('azure-sdk-for-python', 1),
#  ('hacktoberfest2021', 1),
#  ('cmd', 1),
#  ('windows-console', 1),
#  ('windows-terminal', 1),
#  ('libraries', 1),
#  ('packages', 1),
#  ('vcpkg', 1),
#  ('codespaces', 1),
#  ('dev-containers', 1),
#  ('github-codespaces', 1),
#  ('remote', 1),
#  ('remote-development', 1),
#  ('visual-studio-codespaces', 1),
#  ('vs', 1),
#  ('docker-compose', 1),
#  ('dockerfile', 1),
#  ('java-debugger', 1),
#  ('vscode-java', 1),
#  ('datascience', 1),
#  ('amp', 1),
#  ('css-framework', 1),
#  ('flexbox', 1),
#  ('milligram', 1),
#  ('minimalist', 1),
#  ('garbage-collector', 1),
#  ('jit', 1),
#  ('xamarin', 1),
#  ('monodevelop', 1),
#  ('linq', 1),
#  ('mozilla', 1),
#  ('cinema', 1),
#  ('directshow', 1),
#  ('evr', 1),
#  ('h264', 1),
#  ('lav-filters', 1),
#  ('lavfilters', 1),
#  ('media-player', 1),
#  ('mkv', 1),
#  ('mpc', 1),
#  ('mpc-hc', 1),
#  ('trac', 1),
#  ('windows-desktop', 1),
#  ('x265', 1),
#  ('xvid', 1),
#  ('libav', 1),
#  ('mplayer', 1),
#  ('mpv', 1),
#  ('openvpn', 1),
#  ('wireguard', 1),
#  ('css-reset', 1),
#  ('normalize-css', 1),
#  ('complex-networks', 1),
#  ('graph-algorithms', 1),
#  ('graph-analysis', 1),
#  ('graph-generation', 1),
#  ('graph-theory', 1),
#  ('graph-visualization', 1),
#  ('js', 1),
#  ('mit', 1),
#  ('node', 1),
#  ('notepad', 1),
#  ('notepad-official', 1),
#  ('size-optimization', 1),
#  ('vhdx', 1),
#  ('wsl2', 1),
#  ('changelog', 1),
#  ('history', 1),
#  ('release', 1),
#  ('tag', 1),
#  ('versioning', 1),
#  ('msys2', 1),
#  ('rubyinstaller', 1),
#  ('openjdk', 1),
#  ('cryptography', 1),
#  ('file-sharing', 1),
#  ('keychain', 1),
#  ('login', 1),
#  ('opera-addon', 1),
#  ('stylish', 1),
#  ('usercss', 1),
#  ('userstyles', 1),
#  ('alignment', 1),
#  ('data-analysis', 1),
#  ('flexible', 1),
#  ('pandas', 1),
#  ('chatgpt', 1),
#  ('exporter', 1),
#  ('tampermonkey', 1),
#  ('gem', 1),
#  ('icons', 1),
#  ('jekyll', 1),
#  ('octicons', 1),
#  ('octicons-helper', 1),
#  ('primer', 1),
#  ('creative-coding', 1),
#  ('graphics', 1),
#  ('p5js', 1),
#  ('sound', 1),
#  ('pde', 1),
#  ('debugger', 1),
#  ('introspection', 1),
#  ('irb', 1),
#  ('pry', 1),
#  ('reflection', 1),
#  ('forhumans', 1),
#  ('humans', 1),
#  ('python-requests', 1),
#  ('requests', 1),
#  ('linting', 1),
#  ('webassembly', 1),
#  ('pipfile', 1),
#  ('virtualenv', 1),
#  ('pypi', 1),
#  ('venv', 1),
#  ('test', 1),
#  ('attributes', 1),
#  ('boilerplate', 1),
#  ('classes', 1),
#  ('oop', 1),
#  ('dependency-manager', 1),
#  ('poetry', 1),
#  ('typechecker', 1),
#  ('stub', 1),
#  ('bittorrent-client', 1),
#  ('crossplatform', 1),
#  ('torrent-client', 1),
#  ('plugin', 1),
#  ('qbittorrent', 1),
#  ('search-engine', 1),
#  ('live-reload', 1),
#  ('live-server', 1),
#  ('livereload', 1),
#  ('diagnostics', 1),
#  ('addin', 1),
#  ('com', 1),
#  ('com-interop', 1),
#  ('dot-net', 1),
#  ('indentation', 1),
#  ('ms-office', 1),
#  ('parsing', 1),
#  ('parsing-expression-grammar', 1),
#  ('vb6', 1),
#  ('vba', 1),
#  ('vba-ide', 1),
#  ('best-practices', 1),
#  ('style', 1),
#  ('code-formatter', 1),
#  ('object-oriented', 1),
#  ('rubygems', 1),
#  ('book', 1),
#  ('mdbook', 1),
#  ('rust-programming-language', 1),
#  ('desktop-application', 1),
#  ('first-person-shooter', 1),
#  ('fmod', 1),
#  ('game', 1),
#  ('opengl', 1),
#  ('source-port', 1),
#  ('cad', 1),
#  ('parametric', 1),
#  ('graalvm', 1),
#  ('animation', 1),
#  ('svgjs', 1),
#  ('drawing', 1),
#  ('visualization', 1),
#  ('computer-algebra', 1),
#  ('science', 1),
#  ('toml-parser', 1),
#  ('checker', 1),
#  ('hyperlinks', 1),
#  ('messenger', 1),
#  ('multi-platform', 1),
#  ('telegram', 1),
#  ('telegram-desktop', 1),
#  ('telegram-solution', 1),
#  ('audacity', 1),
#  ('audio-applications', 1),
#  ('audio-processing', 1),
#  ('libre', 1),
#  ('privacy-friendly', 1),
#  ('privacy-preserving', 1),
#  ('recorder', 1),
#  ('recording-app', 1),
#  ('lstm', 1),
#  ('ocr', 1),
#  ('ocr-engine', 1),
#  ('tesseract', 1),
#  ('tesseract-ocr', 1),
#  ('algorithm', 1),
#  ('computer-science', 1),
#  ('interview', 1),
#  ('interview-preparation', 1),
#  ('javascript-algorithms', 1),
#  ('interpreter', 1),
#  ('javascript-engine', 1),
#  ('element', 1),
#  ('element-web', 1),
#  ('matrix', 1),
#  ('matrix-chat', 1),
#  ('lgpl', 1),
#  ('libvlc', 1),
#  ('videolan', 1),
#  ('vim-plugin', 1),
#  ('text-editor', 1),
#  ('userscripts-support', 1),
#  ('violentmonkey', 1),
#  ('webextensions', 1),
#  ('android-app', 1),
#  ('mediawiki-api', 1),
#  ('rest-api', 1),
#  ('rxjava-android', 1),
#  ('wikipedia-android', 1),
#  ('compilation', 1),
#  ('compiler-explorer', 1),
#  ('godbolt', 1),
#  ('bootstrap5', 1),
#  ('gist', 1),
#  ('neutrino', 1),
#  ('playground', 1),
#  ('react', 1),
#  ('tornado', 1),
#  ('hamachi', 1),
#  ('meson', 1),
#  ('vala', 1)]

# %%
len(_)
# Out:
# 916

# %%
topics['containers']
# Out:
# ['devcontainers/feature-starter',
#  'devcontainers/features',
#  'devcontainers/images',
#  'devcontainers/spec',
#  'lizrice/containers-from-scratch',
#  'meaningful-ooo/devcontainer-features',
#  'microsoft/vscode-dev-containers']

# %%
topics['devcontainers']
# Out:
# ['devcontainers/feature-starter',
#  'devcontainers/features',
#  'devcontainers/images',
#  'devcontainers/spec',
#  'meaningful-ooo/devcontainer-features',
#  'microsoft/vscode-dev-containers',
#  'rocker-org/devcontainer-features']
