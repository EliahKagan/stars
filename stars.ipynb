# %% [markdown]
# # GitHub Stars

# %%
import itertools
import json
import requests

# %%
def _ensure_list(part_or_whole):
    if not isinstance(part_or_whole, list):
        typename = type(part_or_whole).__name__
        raise TypeError(f"result is {typename!r}, expected 'list'")

# %%
def _fetch_starred_repos(user: str) -> list[dict]:
    """Fetch GitHub repositories starred by a user, via the GitHub REST API."""
    repos = []

    for page in itertools.count(1):
        url = f'https://api.github.com/users/{user}/starred?page={page}'
        response = requests.get(url)
        response.raise_for_status()
        part = response.json()
        _ensure_list(part)

        if not part:
            break

        repos.extend(part)

    return repos

# %%
def get_starred_repos(user: str) -> list[dict]:
    """Get GitHub repositories starred by a user, with disk caching."""
    path = f'starred-repos-{user}.json'

    try:
        # Attempted to load a saved result instead of calling the API.
        with open(path, mode='r', encoding='utf-8') as file:
            repos = json.load(file)
    except OSError:
        # They were not saved. Fetch them from the API and save them.
        repos = _fetch_starred_repos(user)
        with open(path, mode='w', encoding='utf-8') as file:
            json.dump(obj=repos, fp=file)
    else:
        # They were saved. Check that JSON decoded to the correct type.
        _ensure_list(repos)

    return repos

# %%
sr = get_starred_repos('EliahKagan')

# %%
sorted(repo['url'] for repo in sr)
# Out:
# ['https://api.github.com/repos/AbiWord/abiword',
#  'https://api.github.com/repos/AdamMaras/vscode-overtype',
#  'https://api.github.com/repos/ArtOfCode-/Sentinel',
#  'https://api.github.com/repos/AvaloniaUI/Avalonia',
#  'https://api.github.com/repos/AvaloniaUI/AvaloniaVS',
#  'https://api.github.com/repos/BLAKE3-team/BLAKE3',
#  'https://api.github.com/repos/Briles/gruvbox',
#  'https://api.github.com/repos/Calinou/scoop-games',
#  'https://api.github.com/repos/Charcoal-SE/SmokeDetector',
#  'https://api.github.com/repos/Charcoal-SE/metasmoke',
#  'https://api.github.com/repos/Charcoal-SE/userscripts',
#  'https://api.github.com/repos/Cimbali/markdown-viewer',
#  'https://api.github.com/repos/CommunityToolkit/WindowsCommunityToolkit',
#  'https://api.github.com/repos/Debian/apt',
#  'https://api.github.com/repos/DonJayamanne/gitHistoryVSCode',
#  'https://api.github.com/repos/DonJayamanne/pythonVSCode',
#  'https://api.github.com/repos/Doom-Utils/xwadtools',
#  'https://api.github.com/repos/EFForg/https-everywhere',
#  'https://api.github.com/repos/EFForg/privacybadger',
#  'https://api.github.com/repos/FasterXML/jackson',
#  'https://api.github.com/repos/FasterXML/jackson-core',
#  'https://api.github.com/repos/FasterXML/jackson-databind',
#  'https://api.github.com/repos/GNOME/brasero',
#  'https://api.github.com/repos/GNOME/cantarell-fonts',
#  'https://api.github.com/repos/GNOME/evince',
#  'https://api.github.com/repos/GNOME/file-roller',
#  'https://api.github.com/repos/GNOME/gedit',
#  'https://api.github.com/repos/GNOME/gimp',
#  'https://api.github.com/repos/GNOME/glade',
#  'https://api.github.com/repos/GNOME/glib',
#  'https://api.github.com/repos/GNOME/glibmm',
#  'https://api.github.com/repos/GNOME/gnome-control-center',
#  'https://api.github.com/repos/GNOME/gnome-panel',
#  'https://api.github.com/repos/GNOME/gnome-shell',
#  'https://api.github.com/repos/GNOME/gnumeric',
#  'https://api.github.com/repos/GNOME/gparted',
#  'https://api.github.com/repos/GNOME/gspell',
#  'https://api.github.com/repos/GNOME/gtk',
#  'https://api.github.com/repos/GNOME/gtkmm',
#  'https://api.github.com/repos/GNOME/gtksourceview',
#  'https://api.github.com/repos/GNOME/gvfs',
#  'https://api.github.com/repos/GNOME/meld',
#  'https://api.github.com/repos/GNOME/nautilus',
#  'https://api.github.com/repos/GNOME/rhythmbox',
#  'https://api.github.com/repos/GNOME/seahorse',
#  'https://api.github.com/repos/GNOME/vala',
#  'https://api.github.com/repos/GitCredentialManager/git-credential-manager',
#  'https://api.github.com/repos/Glorfindel83/SE-Userscripts',
#  'https://api.github.com/repos/GtkSharp/GtkSharp',
#  'https://api.github.com/repos/IBM/plex',
#  'https://api.github.com/repos/IronLanguages/ironpython2',
#  'https://api.github.com/repos/IronLanguages/ironpython3',
#  'https://api.github.com/repos/Jackett/Jackett',
#  'https://api.github.com/repos/James-Yu/LaTeX-Workshop',
#  'https://api.github.com/repos/JamesNK/Newtonsoft.Json',
#  'https://api.github.com/repos/JetBrains/JetBrainsMono',
#  'https://api.github.com/repos/JetBrains/intellij-community',
#  'https://api.github.com/repos/JetBrains/kotlin',
#  'https://api.github.com/repos/JustusAdam/language-haskell',
#  'https://api.github.com/repos/KDE/dolphin',
#  'https://api.github.com/repos/KDE/kate',
#  'https://api.github.com/repos/KDE/konqueror',
#  'https://api.github.com/repos/KDE/plasma-desktop',
#  'https://api.github.com/repos/KDE/plasma-workspace',
#  'https://api.github.com/repos/KaTeX/KaTeX',
#  'https://api.github.com/repos/Kitware/CMake',
#  'https://api.github.com/repos/LibreOffice/core',
#  'https://api.github.com/repos/LuaJIT/LuaJIT',
#  'https://api.github.com/repos/MaartenBaert/ssr',
#  'https://api.github.com/repos/Maximus5/ConEmu',
#  'https://api.github.com/repos/MicrosoftDocs/PowerShell-Docs',
#  'https://api.github.com/repos/MicrosoftDocs/WSL',
#  'https://api.github.com/repos/MicrosoftDocs/live-share',
#  'https://api.github.com/repos/MicrosoftDocs/quantum-docs',
#  'https://api.github.com/repos/Mimino666/langdetect',
#  'https://api.github.com/repos/MousaZeidBaker/poetry-plugin-up',
#  'https://api.github.com/repos/MousaZeidBaker/poetryup',
#  'https://api.github.com/repos/NuGet/NuGetGallery',
#  'https://api.github.com/repos/NuGetPackageExplorer/NuGetPackageExplorer',
#  'https://api.github.com/repos/NulAsh/cpython',
#  'https://api.github.com/repos/OpenVPN/openvpn',
#  'https://api.github.com/repos/Perl/perl5',
#  'https://api.github.com/repos/PowerShell/PSScriptAnalyzer',
#  'https://api.github.com/repos/PowerShell/PowerShell',
#  'https://api.github.com/repos/PowerShell/Win32-OpenSSH',
#  'https://api.github.com/repos/PowerShell/openssh-portable',
#  'https://api.github.com/repos/PowerShell/vscode-powershell',
#  'https://api.github.com/repos/PureDarwin/PureDarwin',
#  'https://api.github.com/repos/PyCQA/flake8',
#  'https://api.github.com/repos/PyCQA/isort',
#  'https://api.github.com/repos/PyCQA/mccabe',
#  'https://api.github.com/repos/PyCQA/pycodestyle',
#  'https://api.github.com/repos/PyCQA/pyflakes',
#  'https://api.github.com/repos/PyCQA/pylint',
#  'https://api.github.com/repos/PyO3/pyo3',
#  'https://api.github.com/repos/RedHatOfficial/RedHatFont',
#  'https://api.github.com/repos/RobertBeckebans/RBDOOM-3-BFG',
#  'https://api.github.com/repos/RobertCraigie/pyright-python',
#  'https://api.github.com/repos/SOBotics/Natty',
#  'https://api.github.com/repos/SOBotics/chatexchange',
#  'https://api.github.com/repos/ScoopInstaller/Extras',
#  'https://api.github.com/repos/ScoopInstaller/Java',
#  'https://api.github.com/repos/ScoopInstaller/Main',
#  'https://api.github.com/repos/ScoopInstaller/Scoop',
#  'https://api.github.com/repos/StackExchange/StackExchange.DataExplorer',
#  'https://api.github.com/repos/StackExchange/Stacks',
#  'https://api.github.com/repos/StephenCleary/Comparers',
#  'https://api.github.com/repos/StephenCleary/Deque',
#  'https://api.github.com/repos/SublimeText/PowerShell',
#  'https://api.github.com/repos/Syncplay/syncplay',
#  'https://api.github.com/repos/TTimo/doom3.gpl',
#  'https://api.github.com/repos/TheAlgorithms/Rust',
#  'https://api.github.com/repos/TheoKanning/openai-java',
#  'https://api.github.com/repos/TorrSamaho/zandronum',
#  'https://api.github.com/repos/UlionTse/translators',
#  'https://api.github.com/repos/VSCodium/vscodium',
#  'https://api.github.com/repos/Videonauth/ProtonDB-Bot',
#  'https://api.github.com/repos/XQuartz/XQuartz',
#  'https://api.github.com/repos/XQuartz/xorg-server',
#  'https://api.github.com/repos/Xilinx/qemu',
#  'https://api.github.com/repos/Z3Prover/z3',
#  'https://api.github.com/repos/ZDoom/gzdoom',
#  'https://api.github.com/repos/ZDoom/qzdoom',
#  'https://api.github.com/repos/actions/checkout',
#  'https://api.github.com/repos/actions/runner-images',
#  'https://api.github.com/repos/actions/setup-dotnet',
#  'https://api.github.com/repos/actions/setup-java',
#  'https://api.github.com/repos/actions/setup-python',
#  'https://api.github.com/repos/actions/upload-artifact',
#  'https://api.github.com/repos/adobe-fonts/source-code-pro',
#  'https://api.github.com/repos/adobe-fonts/source-sans',
#  'https://api.github.com/repos/adobe-fonts/source-serif',
#  'https://api.github.com/repos/adobe/brackets',
#  'https://api.github.com/repos/adoxa/ansicon',
#  'https://api.github.com/repos/albahari/uncapsulator',
#  'https://api.github.com/repos/alefragnani/vscode-numbered-bookmarks',
#  'https://api.github.com/repos/alexmojaki/cheap_repr',
#  'https://api.github.com/repos/alignedai/chatgpt-prompt-evaluator',
#  'https://api.github.com/repos/apache/maven',
#  'https://api.github.com/repos/arvidn/libtorrent',
#  'https://api.github.com/repos/astanin/python-tabulate',
#  'https://api.github.com/repos/atom-community/atom',
#  'https://api.github.com/repos/atom/atom',
#  'https://api.github.com/repos/auth0/kbd',
#  'https://api.github.com/repos/azemoh/vscode-one-monokai',
#  'https://api.github.com/repos/baSSiLL/SharpAvi',
#  'https://api.github.com/repos/bash-lsp/bash-language-server',
#  'https://api.github.com/repos/bbusschots/hsxkpasswd',
#  'https://api.github.com/repos/beautify-web/js-beautify',
#  'https://api.github.com/repos/bewuethr/shellcheck-action',
#  'https://api.github.com/repos/borisdayma/dalle-mini',
#  'https://api.github.com/repos/bower/bower',
#  'https://api.github.com/repos/brackets-cont/brackets',
#  'https://api.github.com/repos/bryanbraun/anchorjs',
#  'https://api.github.com/repos/bungcip/better-toml',
#  'https://api.github.com/repos/canonical/apport',
#  'https://api.github.com/repos/canonical/lightdm',
#  'https://api.github.com/repos/carbon-language/carbon-lang',
#  'https://api.github.com/repos/cebix/macemu',
#  'https://api.github.com/repos/chengyin/WhatFont-Bookmarklet',
#  'https://api.github.com/repos/chocolate-doom/chocolate-doom',
#  'https://api.github.com/repos/chromium/chromium',
#  'https://api.github.com/repos/clangd/clangd',
#  'https://api.github.com/repos/clangd/vscode-clangd',
#  'https://api.github.com/repos/clsid2/mpc-hc',
#  'https://api.github.com/repos/colesbury/nogil',
#  'https://api.github.com/repos/colesbury/nogil-3.12',
#  'https://api.github.com/repos/colesbury/nogil-wheels',
#  'https://api.github.com/repos/compiler-explorer/compiler-explorer',
#  'https://api.github.com/repos/conda-forge/conda-forge.github.io',
#  'https://api.github.com/repos/conda-forge/graphviz-feedstock',
#  'https://api.github.com/repos/conda-forge/greenlet-feedstock',
#  'https://api.github.com/repos/conda-forge/miniforge',
#  'https://api.github.com/repos/conda-forge/mypy-feedstock',
#  'https://api.github.com/repos/conda-forge/pyright-feedstock',
#  'https://api.github.com/repos/conda-forge/python-feedstock',
#  'https://api.github.com/repos/conda/conda',
#  'https://api.github.com/repos/conradkleinespel/rprompt',
#  'https://api.github.com/repos/crystal-community/icr',
#  'https://api.github.com/repos/crystal-lang-tools/vscode-crystal-lang',
#  'https://api.github.com/repos/crystal-lang/crystal',
#  'https://api.github.com/repos/crystal-lang/crystal-book',
#  'https://api.github.com/repos/csachs/pyproject-flake8',
#  'https://api.github.com/repos/curl/curl',
#  'https://api.github.com/repos/dahlbyk/posh-git',
#  'https://api.github.com/repos/dannguyen/abbyy-finereader-ocr-senate',
#  'https://api.github.com/repos/darkreader/darkreader',
#  'https://api.github.com/repos/datadriventests/ddt',
#  'https://api.github.com/repos/dependabot/dependabot-core',
#  'https://api.github.com/repos/devcontainers/feature-starter',
#  'https://api.github.com/repos/devcontainers/features',
#  'https://api.github.com/repos/devcontainers/images',
#  'https://api.github.com/repos/devcontainers/spec',
#  'https://api.github.com/repos/devcontainers/template-starter',
#  'https://api.github.com/repos/dmvassallo/cgrep',
#  'https://api.github.com/repos/dockerfile/python',
#  'https://api.github.com/repos/dotnet/cli-lab',
#  'https://api.github.com/repos/dotnet/core',
#  'https://api.github.com/repos/dotnet/csharpstandard',
#  'https://api.github.com/repos/dotnet/docs',
#  'https://api.github.com/repos/dotnet/fsharp',
#  'https://api.github.com/repos/dotnet/interactive',
#  'https://api.github.com/repos/dotnet/msbuild',
#  'https://api.github.com/repos/dotnet/roslyn',
#  'https://api.github.com/repos/dotnet/roslyn-analyzers',
#  'https://api.github.com/repos/dotnet/roslyn-sdk',
#  'https://api.github.com/repos/dotnet/runtime',
#  'https://api.github.com/repos/dotnet/sdk',
#  'https://api.github.com/repos/dotnet/source-indexer',
#  'https://api.github.com/repos/dotnet/upgrade-assistant',
#  'https://api.github.com/repos/dotnet/winforms',
#  'https://api.github.com/repos/dotnet/winforms-datavisualization',
#  'https://api.github.com/repos/dpacassi/disable-javascript',
#  'https://api.github.com/repos/dreampuf/GraphvizOnline',
#  'https://api.github.com/repos/eclipse/openvsx',
#  'https://api.github.com/repos/eliheuer/caskaydia-cove',
#  'https://api.github.com/repos/emacs-mirror/emacs',
#  'https://api.github.com/repos/emilybache/Phone-Numbers-Kata',
#  'https://api.github.com/repos/explosion/spaCy',
#  'https://api.github.com/repos/explosion/spacy-models',
#  'https://api.github.com/repos/explosion/spacy-transformers',
#  'https://api.github.com/repos/fabric/fabric',
#  'https://api.github.com/repos/faster-cpython/cpython',
#  'https://api.github.com/repos/faster-cpython/ideas',
#  'https://api.github.com/repos/fish-shell/fish-shell',
#  'https://api.github.com/repos/fluentpython/book-site',
#  'https://api.github.com/repos/fluentpython/example-code-2e',
#  'https://api.github.com/repos/fmtlib/fmt',
#  'https://api.github.com/repos/freebsd/freebsd-doc',
#  'https://api.github.com/repos/freebsd/freebsd-src',
#  'https://api.github.com/repos/freedesktop/NetworkManager',
#  'https://api.github.com/repos/freedesktop/polkit',
#  'https://api.github.com/repos/freedesktop/xorg-xserver',
#  'https://api.github.com/repos/fsharp/TryFSharp',
#  'https://api.github.com/repos/fsharp/fsharp',
#  'https://api.github.com/repos/gaul/awesome-ld-preload',
#  'https://api.github.com/repos/gaurav-nelson/github-action-markdown-link-check',
#  'https://api.github.com/repos/gcc-mirror/gcc',
#  'https://api.github.com/repos/ghc/ghc',
#  'https://api.github.com/repos/giampaolo/psutil',
#  'https://api.github.com/repos/git-for-windows/git',
#  'https://api.github.com/repos/git/git',
#  'https://api.github.com/repos/gitextensions/gitextensions',
#  'https://api.github.com/repos/github/codeql-action',
#  'https://api.github.com/repos/github/docs',
#  'https://api.github.com/repos/github/gitignore',
#  'https://api.github.com/repos/github/linguist',
#  'https://api.github.com/repos/gitkraken/vscode-gitlens',
#  'https://api.github.com/repos/gitlabhq/gitlabhq',
#  'https://api.github.com/repos/google/fonts',
#  'https://api.github.com/repos/google/model-viewer',
#  'https://api.github.com/repos/googlefonts/Inconsolata',
#  'https://api.github.com/repos/googlefonts/NunitoSans',
#  'https://api.github.com/repos/googlefonts/Raleway',
#  'https://api.github.com/repos/googlefonts/nunito',
#  'https://api.github.com/repos/googlefonts/opensans',
#  'https://api.github.com/repos/googlefonts/plex',
#  'https://api.github.com/repos/googlefonts/source-serif-pro',
#  'https://api.github.com/repos/gorhill/uBlock',
#  'https://api.github.com/repos/greasemonkey/greasemonkey',
#  'https://api.github.com/repos/guiyomh/features',
#  'https://api.github.com/repos/haskell/vscode-haskell',
#  'https://api.github.com/repos/huggingface/huggingface_hub',
#  'https://api.github.com/repos/huggingface/safetensors',
#  'https://api.github.com/repos/huggingface/transformers',
#  'https://api.github.com/repos/hylang/hy',
#  'https://api.github.com/repos/iamdustan/smoothscroll',
#  'https://api.github.com/repos/icsharpcode/AvaloniaILSpy',
#  'https://api.github.com/repos/icsharpcode/ILSpy',
#  'https://api.github.com/repos/id-Software/DOOM',
#  'https://api.github.com/repos/id-Software/DOOM-3',
#  'https://api.github.com/repos/id-Software/DOOM-3-BFG',
#  'https://api.github.com/repos/id-Software/Enemy-Territory',
#  'https://api.github.com/repos/id-Software/Quake',
#  'https://api.github.com/repos/id-Software/Quake-2',
#  'https://api.github.com/repos/id-Software/Quake-III-Arena',
#  'https://api.github.com/repos/id-Software/RTCW-MP',
#  'https://api.github.com/repos/id-Software/RTCW-SP',
#  'https://api.github.com/repos/id-Software/quake-rerelease-qc',
#  'https://api.github.com/repos/id-Software/wolf3d',
#  'https://api.github.com/repos/impallari/Raleway',
#  'https://api.github.com/repos/ipython/ipykernel',
#  'https://api.github.com/repos/ipython/ipython',
#  'https://api.github.com/repos/jakebailey/pyright-action',
#  'https://api.github.com/repos/jd/tenacity',
#  'https://api.github.com/repos/jdinhify/vscode-theme-gruvbox',
#  'https://api.github.com/repos/jessicarumbelow/Backwards',
#  'https://api.github.com/repos/jgm/pandoc',
#  'https://api.github.com/repos/jgonggrijp/pip-review',
#  'https://api.github.com/repos/jitsi/jitsi-meet',
#  'https://api.github.com/repos/jitsi/jitsi-meet-electron',
#  'https://api.github.com/repos/jmazouri/SharpPad',
#  'https://api.github.com/repos/jncraton/doctestfn',
#  'https://api.github.com/repos/john-hen/Flake8-pyproject',
#  'https://api.github.com/repos/johnpapa/vscode-peacock',
#  'https://api.github.com/repos/jpetrucciani/mypy-check',
#  'https://api.github.com/repos/jruby/jruby',
#  'https://api.github.com/repos/jsuarezruiz/maui-linux',
#  'https://api.github.com/repos/jupyter-server/jupyter_server',
#  'https://api.github.com/repos/jupyter/jupyter',
#  'https://api.github.com/repos/jupyter/jupyter_client',
#  'https://api.github.com/repos/jupyter/jupyter_core',
#  'https://api.github.com/repos/jupyter/nbdime',
#  'https://api.github.com/repos/jupyter/nbformat',
#  'https://api.github.com/repos/jupyter/notebook',
#  'https://api.github.com/repos/jupyterlab/jupyterlab',
#  'https://api.github.com/repos/jupyterlab/jupyterlab-git',
#  'https://api.github.com/repos/jupyterlab/jupyterlab_server',
#  'https://api.github.com/repos/killercup/cargo-edit',
#  'https://api.github.com/repos/koalaman/shellcheck',
#  'https://api.github.com/repos/koalaman/shellcheck.net',
#  'https://api.github.com/repos/lebedov/msgpack-numpy',
#  'https://api.github.com/repos/lemon24/typeless-dataclasses',
#  'https://api.github.com/repos/lewissbaker/cppcoro',
#  'https://api.github.com/repos/libgit2/pygit2',
#  'https://api.github.com/repos/licensee/licensee',
#  'https://api.github.com/repos/litl/backoff',
#  'https://api.github.com/repos/lizrice/containers-from-scratch',
#  'https://api.github.com/repos/llvm-mirror/compiler-rt',
#  'https://api.github.com/repos/llvm-mirror/libcxx',
#  'https://api.github.com/repos/llvm-mirror/libcxxabi',
#  'https://api.github.com/repos/llvm-mirror/llvm',
#  'https://api.github.com/repos/lua/lua',
#  'https://api.github.com/repos/lukewiwa/features',
#  'https://api.github.com/repos/lxde/libfm',
#  'https://api.github.com/repos/lxde/lxappearance',
#  'https://api.github.com/repos/lxde/lxde-common',
#  'https://api.github.com/repos/lxde/lxde-icon-theme',
#  'https://api.github.com/repos/lxde/lxpanel',
#  'https://api.github.com/repos/lxde/lxrandr',
#  'https://api.github.com/repos/lxde/lxsession',
#  'https://api.github.com/repos/lxde/lxtask',
#  'https://api.github.com/repos/lxde/lxterminal',
#  'https://api.github.com/repos/lxde/pcmanfm',
#  'https://api.github.com/repos/lxqt/libfm-qt',
#  'https://api.github.com/repos/lxqt/libqtxdg',
#  'https://api.github.com/repos/lxqt/lxqt',
#  'https://api.github.com/repos/lxqt/lxqt-archiver',
#  'https://api.github.com/repos/lxqt/lxqt-config',
#  'https://api.github.com/repos/lxqt/lxqt-panel',
#  'https://api.github.com/repos/lxqt/lxqt-policykit',
#  'https://api.github.com/repos/lxqt/lxqt-runner',
#  'https://api.github.com/repos/lxqt/lxqt-session',
#  'https://api.github.com/repos/lxqt/lxqt-sudo',
#  'https://api.github.com/repos/lxqt/pavucontrol-qt',
#  'https://api.github.com/repos/lxqt/pcmanfm-qt',
#  'https://api.github.com/repos/lxqt/qps',
#  'https://api.github.com/repos/lxqt/qterminal',
#  'https://api.github.com/repos/madmaze/pytesseract',
#  'https://api.github.com/repos/magjac/d3-graphviz',
#  'https://api.github.com/repos/mamba-org/mamba',
#  'https://api.github.com/repos/matplotlib/matplotlib',
#  'https://api.github.com/repos/mdaines/viz.js',
#  'https://api.github.com/repos/mdn/content',
#  'https://api.github.com/repos/mdn/learning-area',
#  'https://api.github.com/repos/meaningful-ooo/devcontainer-features',
#  'https://api.github.com/repos/mhutchie/vscode-git-graph',
#  'https://api.github.com/repos/michaelhue/keyscss',
#  'https://api.github.com/repos/microsoft/Quantum',
#  'https://api.github.com/repos/microsoft/QuantumKatas',
#  'https://api.github.com/repos/microsoft/QuantumLibraries',
#  'https://api.github.com/repos/microsoft/STL',
#  'https://api.github.com/repos/microsoft/Selawik',
#  'https://api.github.com/repos/microsoft/WSL2-Linux-Kernel',
#  'https://api.github.com/repos/microsoft/automatic-graph-layout',
#  'https://api.github.com/repos/microsoft/cascadia-code',
#  'https://api.github.com/repos/microsoft/infersharp',
#  'https://api.github.com/repos/microsoft/infersharpaction',
#  'https://api.github.com/repos/microsoft/iqsharp',
#  'https://api.github.com/repos/microsoft/monaco-editor',
#  'https://api.github.com/repos/microsoft/psscriptanalyzer-action',
#  'https://api.github.com/repos/microsoft/pylance-release',
#  'https://api.github.com/repos/microsoft/pyright',
#  'https://api.github.com/repos/microsoft/qdk-python',
#  'https://api.github.com/repos/microsoft/qsharp-compiler',
#  'https://api.github.com/repos/microsoft/qsharp-language',
#  'https://api.github.com/repos/microsoft/qsharp-runtime',
#  'https://api.github.com/repos/microsoft/terminal',
#  'https://api.github.com/repos/microsoft/vcpkg',
#  'https://api.github.com/repos/microsoft/vcpkg-docs',
#  'https://api.github.com/repos/microsoft/vcpkg-tool',
#  'https://api.github.com/repos/microsoft/vscode',
#  'https://api.github.com/repos/microsoft/vscode-cmake-tools',
#  'https://api.github.com/repos/microsoft/vscode-dev-containers',
#  'https://api.github.com/repos/microsoft/vscode-docker',
#  'https://api.github.com/repos/microsoft/vscode-java-debug',
#  'https://api.github.com/repos/microsoft/vscode-jupyter',
#  'https://api.github.com/repos/microsoft/vscode-notebook-renderers',
#  'https://api.github.com/repos/microsoft/vscode-python',
#  'https://api.github.com/repos/microsoft/vscode-remote-try-cpp',
#  'https://api.github.com/repos/microsoft/vscode-remote-try-dotnet',
#  'https://api.github.com/repos/microsoft/vscode-remote-try-python',
#  'https://api.github.com/repos/milligram/milligram',
#  'https://api.github.com/repos/mintty/mintty',
#  'https://api.github.com/repos/mirror/busybox',
#  'https://api.github.com/repos/mirror/wget',
#  'https://api.github.com/repos/mjbvz/vscode-github-markdown-preview-style',
#  'https://api.github.com/repos/mono/corefx',
#  'https://api.github.com/repos/mono/gtk-sharp',
#  'https://api.github.com/repos/mono/mono',
#  'https://api.github.com/repos/mono/mono-basic',
#  'https://api.github.com/repos/mono/monodevelop',
#  'https://api.github.com/repos/more-itertools/more-itertools',
#  'https://api.github.com/repos/morelinq/MoreLINQ',
#  'https://api.github.com/repos/morhetz/gruvbox',
#  'https://api.github.com/repos/mozilla-mobile/fenix',
#  'https://api.github.com/repos/mpc-hc/mpc-hc',
#  'https://api.github.com/repos/mpv-player/mpv',
#  'https://api.github.com/repos/msgpack/msgpack',
#  'https://api.github.com/repos/msgpack/msgpack-python',
#  'https://api.github.com/repos/msh5/pipfile-sort',
#  'https://api.github.com/repos/msys2/MINGW-packages',
#  'https://api.github.com/repos/msys2/MSYS2-packages',
#  'https://api.github.com/repos/msys2/msys2',
#  'https://api.github.com/repos/msys2/msys2-pacman',
#  'https://api.github.com/repos/msys2/msys2-runtime',
#  'https://api.github.com/repos/mullvad/mullvadvpn-app',
#  'https://api.github.com/repos/mypyc/mypyc',
#  'https://api.github.com/repos/natalie-lang/natalie',
#  'https://api.github.com/repos/ncase/polygons',
#  'https://api.github.com/repos/neatorobito/scoop-crystal',
#  'https://api.github.com/repos/necolas/normalize.css',
#  'https://api.github.com/repos/networkx/networkx',
#  'https://api.github.com/repos/nirantak/copytables',
#  'https://api.github.com/repos/nodatime/nodatime',
#  'https://api.github.com/repos/nodejs/node',
#  'https://api.github.com/repos/notepad-plus-plus/notepad-plus-plus',
#  'https://api.github.com/repos/numpy/numpy',
#  'https://api.github.com/repos/oconnor663/blake3-py',
#  'https://api.github.com/repos/okibcn/wslcompact',
#  'https://api.github.com/repos/olivierlacan/keep-a-changelog',
#  'https://api.github.com/repos/oneclick/rubyinstaller2',
#  'https://api.github.com/repos/openai/openai-cookbook',
#  'https://api.github.com/repos/openai/openai-python',
#  'https://api.github.com/repos/openai/tiktoken',
#  'https://api.github.com/repos/openbsd/ports',
#  'https://api.github.com/repos/openbsd/src',
#  'https://api.github.com/repos/openjdk/jdk',
#  'https://api.github.com/repos/openjdk/valhalla',
#  'https://api.github.com/repos/openssh/openssh-portable',
#  'https://api.github.com/repos/openstyles/stylus',
#  'https://api.github.com/repos/pandas-dev/pandas',
#  'https://api.github.com/repos/paramiko/paramiko',
#  'https://api.github.com/repos/phil294/git-log--graph',
#  'https://api.github.com/repos/pionxzh/chatgpt-exporter',
#  'https://api.github.com/repos/poetix/protonpack',
#  'https://api.github.com/repos/primer/octicons',
#  'https://api.github.com/repos/processing/p5.js',
#  'https://api.github.com/repos/processing/p5.js-web-editor',
#  'https://api.github.com/repos/processing/processing',
#  'https://api.github.com/repos/processing/processing4',
#  'https://api.github.com/repos/project64/project64',
#  'https://api.github.com/repos/pry/pry',
#  'https://api.github.com/repos/psf/requests',
#  'https://api.github.com/repos/py-actions/flake8',
#  'https://api.github.com/repos/pyinvoke/invoke',
#  'https://api.github.com/repos/pyodide/pyodide',
#  'https://api.github.com/repos/pypa/pip',
#  'https://api.github.com/repos/pypa/pipenv',
#  'https://api.github.com/repos/pypa/pipx',
#  'https://api.github.com/repos/pytest-dev/pytest',
#  'https://api.github.com/repos/pytest-dev/pytest-subtests',
#  'https://api.github.com/repos/python-attrs/attrs',
#  'https://api.github.com/repos/python-greenlet/greenlet',
#  'https://api.github.com/repos/python-poetry/poetry',
#  'https://api.github.com/repos/python/cpython',
#  'https://api.github.com/repos/python/mypy',
#  'https://api.github.com/repos/python/peps',
#  'https://api.github.com/repos/python/pythondotorg',
#  'https://api.github.com/repos/python/typeshed',
#  'https://api.github.com/repos/python/typing_extensions',
#  'https://api.github.com/repos/qbittorrent/qBittorrent',
#  'https://api.github.com/repos/qbittorrent/search-plugins',
#  'https://api.github.com/repos/qemu/qemu',
#  'https://api.github.com/repos/qt/qt5',
#  'https://api.github.com/repos/qt/qtbase',
#  'https://api.github.com/repos/rechelon/zine_library',
#  'https://api.github.com/repos/redhat-developer/vscode-java',
#  'https://api.github.com/repos/ritwickdey/vscode-live-server',
#  'https://api.github.com/repos/rizonesoft/Notepad3',
#  'https://api.github.com/repos/rocker-org/devcontainer-features',
#  'https://api.github.com/repos/roslynpad/roslynpad',
#  'https://api.github.com/repos/rspec/rspec-core',
#  'https://api.github.com/repos/rspec/rspec-metagem',
#  'https://api.github.com/repos/rubberduck-vba/Rubberduck',
#  'https://api.github.com/repos/rubocop/rspec-style-guide',
#  'https://api.github.com/repos/rubocop/rubocop',
#  'https://api.github.com/repos/rubocop/rubocop-rspec',
#  'https://api.github.com/repos/ruby/ruby',
#  'https://api.github.com/repos/rubygems/rubygems',
#  'https://api.github.com/repos/rubyide/vscode-ruby',
#  'https://api.github.com/repos/rust-lang/book',
#  'https://api.github.com/repos/saarraz/clang-concepts-old',
#  'https://api.github.com/repos/shigma/vscode-wl',
#  'https://api.github.com/repos/simonwhitaker/github-fork-ribbon-css',
#  'https://api.github.com/repos/skyjake/Doomsday-Engine',
#  'https://api.github.com/repos/solvespace/solvespace',
#  'https://api.github.com/repos/square/okhttp',
#  'https://api.github.com/repos/stackless-dev/stackless',
#  'https://api.github.com/repos/stkb/Rewrap',
#  'https://api.github.com/repos/streetsidesoftware/vscode-spell-checker',
#  'https://api.github.com/repos/sudo-project/sudo',
#  'https://api.github.com/repos/svgdotjs/svg.js',
#  'https://api.github.com/repos/swharden/Csharp-Data-Visualization',
#  'https://api.github.com/repos/sylinrl/TruthfulQA',
#  'https://api.github.com/repos/sympy/sympy',
#  'https://api.github.com/repos/tamasfe/taplo',
#  'https://api.github.com/repos/tartley/colorama',
#  'https://api.github.com/repos/tcort/markdown-link-check',
#  'https://api.github.com/repos/telegramdesktop/tdesktop',
#  'https://api.github.com/repos/tenacityteam/tenacity-legacy',
#  'https://api.github.com/repos/tesseract-ocr/tesseract',
#  'https://api.github.com/repos/toml-lang/toml',
#  'https://api.github.com/repos/tomoki1207/selectline-statusbar',
#  'https://api.github.com/repos/tonsky/FiraCode',
#  'https://api.github.com/repos/torstenvl/betterls',
#  'https://api.github.com/repos/torvalds/linux',
#  'https://api.github.com/repos/trekhleb/javascript-algorithms',
#  'https://api.github.com/repos/tritao/clang-cli',
#  'https://api.github.com/repos/twxs/vs.language.cmake',
#  'https://api.github.com/repos/v8/v8',
#  'https://api.github.com/repos/vector-im/element-desktop',
#  'https://api.github.com/repos/vernnobile/NunitoFont',
#  'https://api.github.com/repos/videolan/vlc',
#  'https://api.github.com/repos/videolan/vlc-android',
#  'https://api.github.com/repos/videolan/x265',
#  'https://api.github.com/repos/vim-crystal/vim-crystal',
#  'https://api.github.com/repos/vim/vim',
#  'https://api.github.com/repos/violentmonkey/violentmonkey',
#  'https://api.github.com/repos/vyznev/chatjax',
#  'https://api.github.com/repos/wheredoesyourmindgo/gruvbox-concoctis-vscode-theme',
#  'https://api.github.com/repos/wikimedia/apps-android-wikipedia',
#  'https://api.github.com/repos/wikimedia/mediawiki',
#  'https://api.github.com/repos/wine-mirror/wine',
#  'https://api.github.com/repos/wolever/parameterized',
#  'https://api.github.com/repos/xfce-mirror/mousepad',
#  'https://api.github.com/repos/xfce-mirror/thunar',
#  'https://api.github.com/repos/xfce-mirror/thunar-archive-plugin',
#  'https://api.github.com/repos/xfce-mirror/xfce4-panel',
#  'https://api.github.com/repos/xfce-mirror/xfce4-session',
#  'https://api.github.com/repos/xfce-mirror/xfce4-settings',
#  'https://api.github.com/repos/xfce-mirror/xfce4-taskmanager',
#  'https://api.github.com/repos/xfce-mirror/xfce4-terminal',
#  'https://api.github.com/repos/xfce-mirror/xfdesktop',
#  'https://api.github.com/repos/xfce-mirror/xfwm4',
#  'https://api.github.com/repos/xfgusta/cexpl',
#  'https://api.github.com/repos/xflr6/graphviz',
#  'https://api.github.com/repos/ymyzk/mypy-playground',
#  'https://api.github.com/repos/ytdl-org/youtube-dl',
#  'https://api.github.com/repos/ztefn/haguichi',
#  'https://api.github.com/repos/zx2c4/cgit']

# %%
len(_)
# Out:
# 551
